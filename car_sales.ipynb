# %%
import pandas as pd

# %%
df= pd.read_csv("car_sales_2025.csv", header=0, names=["DATE", "CAR", "UNITS_SOLD"])

# %%
df
# Out:
#            DATE       CAR  UNITS_SOLD
# 0    01-02-2025  Alto 800          83
# 1    01-02-2025   Mustang          99
# 2    01-02-2025      Urus         161
# 3    01-02-2025    Baleno         103
# 4    01-02-2025  Fortuner          55
# ..          ...       ...         ...
# 160  16-03-2025      Echo         180
# 161  16-03-2025     Creta          52
# 162  16-03-2025    Harier           5
# 163  16-03-2025   XUV 300          18
# 164  16-03-2025  Maserati          60
#
# [165 rows x 3 columns]

# %%
df.head()
# Out:
#          DATE       CAR  UNITS_SOLD
# 0  01-02-2025  Alto 800          83
# 1  01-02-2025   Mustang          99
# 2  01-02-2025      Urus         161
# 3  01-02-2025    Baleno         103
# 4  01-02-2025  Fortuner          55

# %%
df.tail()
# Out:
#            DATE       CAR  UNITS_SOLD
# 160  16-03-2025      Echo         180
# 161  16-03-2025     Creta          52
# 162  16-03-2025    Harier           5
# 163  16-03-2025   XUV 300          18
# 164  16-03-2025  Maserati          60

# %%
df.count()
# Out:
# DATE          165
# CAR           165
# UNITS_SOLD    165
# dtype: int64

# %%
df.groupby(["CAR"]).sum()
# Out:
#                                                        DATE  UNITS_SOLD
# CAR
# Alto 800  01-02-202504-01-202504-03-202505-01-202505-02-...        1124
# Baleno    01-02-202504-01-202504-03-202505-01-202505-02-...        1402
# Bolero    01-02-202504-01-202504-03-202505-01-202505-02-...        1321
# Creta     01-02-202504-01-202504-03-202505-01-202505-02-...        1610
# Echo      01-02-202504-01-202504-03-202505-01-202505-02-...        2204
# Fortuner  01-02-202504-01-202504-03-202505-01-202505-02-...        1385
# Harier    01-02-202504-01-202504-03-202505-01-202505-02-...        1576
# Maserati  01-02-202504-01-202504-03-202505-01-202505-02-...        1444
# Mustang   01-02-202504-01-202504-03-202505-01-202505-02-...        1477
# Urus      01-02-202504-01-202504-03-202505-01-202505-02-...        1522
# XUV 300   01-02-202504-01-202504-03-202505-01-202505-02-...        1438

# %%
df.groupby(["CAR"]).count()
# Out:
#           DATE  UNITS_SOLD
# CAR
# Alto 800    15          15
# Baleno      15          15
# Bolero      15          15
# Creta       15          15
# Echo        15          15
# Fortuner    15          15
# Harier      15          15
# Maserati    15          15
# Mustang     15          15
# Urus        15          15
# XUV 300     15          15

# %%
df.DATE[1]
# Out:
# '01-02-2025'

# %%
type(df.DATE[1])
# Out:
# str

# %%
df['DATE']=pd.to_datetime(df['DATE'], dayfirst=True)

# %%
type(df.DATE[1])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df.head()
# Out:
#         DATE       CAR  UNITS_SOLD
# 0 2025-02-01  Alto 800          83
# 1 2025-02-01   Mustang          99
# 2 2025-02-01      Urus         161
# 3 2025-02-01    Baleno         103
# 4 2025-02-01  Fortuner          55

# %%
reshaped_df = df.pivot(index="DATE", columns="CAR", values="UNITS_SOLD")

# %%
reshaped_df
# Out:
# CAR         Alto 800  Baleno  Bolero  Creta  Echo  Fortuner  Harier  Maserati  \
# DATE
# 2025-01-04       154     173      16    151   194       173      56       111
# 2025-01-05       113     103      27    176   150        24     111       150
# 2025-01-08       165      86     119    164   156         7     106       177
# 2025-01-11        54     171     148     33   187       164     185        42
# 2025-01-14        46      97      91    104   122        67       5        38
# 2025-02-01        83     103     125     10   191        55     180        22
# 2025-02-05        11      19      86    103   111       101     189        44
# 2025-02-06       111     100       5     50   192        18      40       193
# 2025-02-13        23      67      64    144   169       184     192        88
# 2025-02-14        96      34      72    148   123       149      55       149
# 2025-03-04        86      36     108    135   109        44      84       119
# ...

# %%
reshaped_df.head()
# Out:
# CAR         Alto 800  Baleno  Bolero  Creta  Echo  Fortuner  Harier  Maserati  \
# DATE
# 2025-01-04       154     173      16    151   194       173      56       111
# 2025-01-05       113     103      27    176   150        24     111       150
# 2025-01-08       165      86     119    164   156         7     106       177
# 2025-01-11        54     171     148     33   187       164     185        42
# 2025-01-14        46      97      91    104   122        67       5        38
#
# CAR         Mustang  Urus  XUV 300
# DATE
# 2025-01-04        6   163       69
# 2025-01-05       74    92       64
# 2025-01-08      133    82       76
# 2025-01-11      148   135      148
# 2025-01-14      139    67       24

# %%
reshaped_df.tail()
# Out:
# CAR         Alto 800  Baleno  Bolero  Creta  Echo  Fortuner  Harier  Maserati  \
# DATE
# 2025-03-04        86      36     108    135   109        44      84       119
# 2025-03-06        87      62     130    154    59       119     159       115
# 2025-03-12        70     178      62     88   197        94      40       127
# 2025-03-14        19      84     147     98    64        28     169         9
# 2025-03-16         6      89     121     52   180       158       5        60
#
# CAR         Mustang  Urus  XUV 300
# DATE
# 2025-03-04       89    23      151
# 2025-03-06       77   184       85
# 2025-03-12       65    87      141
# 2025-03-14      108   167      169
# 2025-03-16      167   128       18

# %%
reshaped_df.shape
# Out:
# (15, 11)

# %%
reshaped_df.count()
# Out:
# CAR
# Alto 800    15
# Baleno      15
# Bolero      15
# Creta       15
# Echo        15
# Fortuner    15
# Harier      15
# Maserati    15
# Mustang     15
# Urus        15
# XUV 300     15
# dtype: int64

# %%
reshaped_df.fillna(0,inplace=True)

# %%
reshaped_df.head()
# Out:
# CAR         Alto 800  Baleno  Bolero  Creta  Echo  Fortuner  Harier  Maserati  \
# DATE
# 2025-01-04       154     173      16    151   194       173      56       111
# 2025-01-05       113     103      27    176   150        24     111       150
# 2025-01-08       165      86     119    164   156         7     106       177
# 2025-01-11        54     171     148     33   187       164     185        42
# 2025-01-14        46      97      91    104   122        67       5        38
#
# CAR         Mustang  Urus  XUV 300
# DATE
# 2025-01-04        6   163       69
# 2025-01-05       74    92       64
# 2025-01-08      133    82       76
# 2025-01-11      148   135      148
# 2025-01-14      139    67       24

# %%
reshaped_df.isna()
# Out:
# CAR         Alto 800  Baleno  Bolero  Creta   Echo  Fortuner  Harier  \
# DATE
# 2025-01-04     False   False   False  False  False     False   False
# 2025-01-05     False   False   False  False  False     False   False
# 2025-01-08     False   False   False  False  False     False   False
# 2025-01-11     False   False   False  False  False     False   False
# 2025-01-14     False   False   False  False  False     False   False
# 2025-02-01     False   False   False  False  False     False   False
# 2025-02-05     False   False   False  False  False     False   False
# 2025-02-06     False   False   False  False  False     False   False
# 2025-02-13     False   False   False  False  False     False   False
# 2025-02-14     False   False   False  False  False     False   False
# 2025-03-04     False   False   False  False  False     False   False
# 2025-03-06     False   False   False  False  False     False   False
# ...

# %%
reshaped_df.isna().sum()
# Out:
# CAR
# Alto 800    0
# Baleno      0
# Bolero      0
# Creta       0
# Echo        0
# Fortuner    0
# Harier      0
# Maserati    0
# Mustang     0
# Urus        0
# XUV 300     0
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(reshaped_df.index,reshaped_df["Mustang"])

# %%
plt.figure(figsize=(16,10))
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.plot(reshaped_df.index,reshaped_df["Mustang"])

# %%
plt.figure(figsize=(16,10))
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel("Date",fontsize=14)
plt.xlabel("Units_Sold",fontsize=14)
plt.ylim(0,300)
plt.plot(reshaped_df.index,reshaped_df["Mustang"])

# %%
plt.figure(figsize=(16,10))
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel("Date",fontsize=14)
plt.xlabel("Units_sold",fontsize=14)
plt.ylim(0,300)
plt.plot(reshaped_df.index,reshaped_df["Alto 800"])
plt.plot(reshaped_df.index,reshaped_df["Baleno"])
plt.plot(reshaped_df.index,reshaped_df["Urus"])
plt.plot(reshaped_df.index,reshaped_df["Fortuner"])
plt.plot(reshaped_df.index,reshaped_df["Echo"])
plt.plot(reshaped_df.index,reshaped_df["Creta"])
plt.plot(reshaped_df.index,reshaped_df["XUV 300"])
plt.plot(reshaped_df.index,reshaped_df["Bolero"])
plt.plot(reshaped_df.index,reshaped_df["Maserati"])
plt.plot(reshaped_df.index,reshaped_df["Harier"])
plt.plot(reshaped_df.index,reshaped_df["Mustang"])

# %%
plt.figure(figsize=(16,10))
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel("Date",fontsize=14)
plt.xlabel("Units_Sold",fontsize=14)
plt.ylim(0,350)
for column in reshaped_df.columns:
    plt.plot (reshaped_df.index,reshaped_df[column],label=reshaped_df[column],linewidth=3)
plt.legend(fontsize=16)
plt.show(block=False)
# Out:
# C:\Users\utsav\AppData\Local\Temp\ipykernel_17360\3632310443.py:8: MatplotlibDeprecationWarning: Passing label as a length 15 sequence when plotting a single dataset is deprecated in Matplotlib 3.9 and will error in 3.11.  To keep the current behavior, cast the sequence to string before passing.
#   plt.plot (reshaped_df.index,reshaped_df[column],label=reshaped_df[column],linewidth=3)

# %%
plt.figure(figsize=(16,10))
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel("Date",fontsize=14)
plt.xlabel("Units_Sold",fontsize=14)
plt.ylim(0,350)
for column in reshaped_df.columns:
    plt.plot (reshaped_df.index,reshaped_df[column],linewidth=3,label=column)
plt.legend(fontsize=16)

# %%
rolling_df = reshaped_df.rolling(window=6).mean()
plt.figure(figsize=(16,10))
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel("Date",fontsize=14)
plt.ylabel("U",fontsize=14)
plt.ylim(0,35000)
for column in reshaped_df.columns:
    plt.plot(reshaped_df.index,rolling_df[column],label=reshaped_df[column],linewidth=3)
plt.legend(fontsize=16)
plt.show(block=False)
