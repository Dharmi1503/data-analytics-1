# %%
import pandas as pd

# %%
df=pd.read_csv("StudentPerformanceFactors.csv")

# %%
df
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23         NaN                  Low                High
# 1                19        64.0                  Low              Medium
# 2                24        98.0               Medium              Medium
# 3                29        89.0                  Low              Medium
# 4                19        92.0               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25        69.0                 High              Medium
# 6603             23        76.0                 High              Medium
# 6604             20        90.0               Medium                 Low
# 6605             10        86.0                 High                High
# 6606             15        67.0               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
df.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23         NaN                  Low                High
# 1             19        64.0                  Low              Medium
# 2             24        98.0               Medium              Medium
# 3             29        89.0                  Low              Medium
# 4             19        92.0               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# ...

# %%
df.head(10)
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23         NaN                  Low                High
# 1             19        64.0                  Low              Medium
# 2             24        98.0               Medium              Medium
# 3             29        89.0                  Low              Medium
# 4             19        92.0               Medium              Medium
# 5             19        88.0               Medium              Medium
# 6             29        84.0               Medium                 Low
# 7             25        78.0                  Low                High
# 8             17        94.0               Medium                High
# 9             23        98.0               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# ...

# %%
df.tail()
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 6602             25        69.0                 High              Medium
# 6603             23        76.0                 High              Medium
# 6604             20        90.0               Medium                 Low
# 6605             10        86.0                 High                High
# 6606             15        67.0               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# 6602                         No            7               76
# 6603                         No            8               81
# 6604                        Yes            6               65
# 6605                        Yes            6               91
# 6606                        Yes            9               94
#
#      Motivation_Level Internet_Access  Tutoring_Sessions Family_Income  \
# 6602           Medium             Yes                1.0          High
# ...

# %%
df.shape
# Out:
# (6607, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6607 entries, 0 to 6606
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Hours_Studied               6607 non-null   int64
#  1   Attendance                  6601 non-null   float64
#  2   Parental_Involvement        6607 non-null   object
#  3   Access_to_Resources         6607 non-null   object
#  4   Extracurricular_Activities  6607 non-null   object
#  5   Sleep_Hours                 6607 non-null   int64
#  6   Previous_Scores             6607 non-null   int64
#  7   Motivation_Level            6607 non-null   object
#  8   Internet_Access             6607 non-null   object
#  9   Tutoring_Sessions           6599 non-null   float64
#  10  Family_Income               6607 non-null   object
#  11  Teacher_Quality             6529 non-null   object
#  12  School_Type                 6607 non-null   object
# ...

# %%
df.describe()
# Out:
#        Hours_Studied   Attendance  Sleep_Hours  Previous_Scores  \
# count    6607.000000  6601.000000   6607.00000      6607.000000
# mean       19.975329    79.985760      7.02906        75.070531
# std         5.990594    11.546445      1.46812        14.399784
# min         1.000000    60.000000      4.00000        50.000000
# 25%        16.000000    70.000000      6.00000        63.000000
# 50%        20.000000    80.000000      7.00000        75.000000
# 75%        24.000000    90.000000      8.00000        88.000000
# max        44.000000   100.000000     10.00000       100.000000
#
#        Tutoring_Sessions  Physical_Activity   Exam_Score
# count        6599.000000        6607.000000  6607.000000
# mean            1.495530           2.967610    67.235659
# std             1.230216           1.031231     3.890456
# min             0.000000           0.000000    55.000000
# 25%             1.000000           2.000000    65.000000
# ...

# %%
df.describe().loc['min']
# Out:
# Hours_Studied         1.0
# Attendance           60.0
# Sleep_Hours           4.0
# Previous_Scores      50.0
# Tutoring_Sessions     0.0
# Physical_Activity     0.0
# Exam_Score           55.0
# Name: min, dtype: float64

# %%
import seaborn as sns
sns.boxplot(df.Exam_Score)
# Out:
# <Axes: ylabel='Exam_Score'>

# %%
df = df[(df['Exam_Score'] >= 60) & (df['Exam_Score'] <= 75)]

# %%
df.shape
# Out:
# (6463, 20)

# %%
sns.boxplot(df.Exam_Score)
# Out:
# <Axes: ylabel='Exam_Score'>

# %%
df=df[['Hours_Studied','Attendance','Sleep_Hours','Previous_Scores','Tutoring_Sessions','Physical_Activity','Exam_Score']]

# %%
df.isna().sum()
# Out:
# Hours_Studied        0
# Attendance           6
# Sleep_Hours          0
# Previous_Scores      0
# Tutoring_Sessions    8
# Physical_Activity    0
# Exam_Score           0
# dtype: int64

# %%
df.head(20)
# Out:
#     Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0              23         NaN                  Low                High
# 1              19        64.0                  Low              Medium
# 2              24        98.0               Medium              Medium
# 3              29        89.0                  Low              Medium
# 4              19        92.0               Medium              Medium
# 5              19        88.0               Medium              Medium
# 6              29        84.0               Medium                 Low
# 7              25        78.0                  Low                High
# 8              17        94.0               Medium                High
# 9              23        98.0               Medium              Medium
# 10             17        80.0                  Low                High
# 11             17        97.0               Medium                High
# ...

# %%
df = df.fillna(df.median())

# %%
df.head(20)
# Out:
#     Hours_Studied  Attendance  Sleep_Hours  Previous_Scores  \
# 0              23        80.0            7               73
# 1              19        64.0            8               59
# 2              24        98.0            7               91
# 3              29        89.0            8               98
# 4              19        92.0            6               65
# 5              19        88.0            8               89
# 6              29        84.0            7               68
# 7              25        78.0            6               50
# 8              17        94.0            6               80
# 9              23        98.0            8               71
# 10             17        80.0            8               88
# 11             17        97.0            6               87
# 12             21        83.0            8               97
# 13              9        82.0            8               72
# 14             10        78.0            8               74
# ...

# %%
df.Hours_Studied.hist()
# Out:
# <Axes: >

# %%
df.Exam_Score.hist()
# Out:
# <Axes: >
